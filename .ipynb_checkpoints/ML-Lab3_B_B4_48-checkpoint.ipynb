# %% [markdown]
# # Practical-3 Machine Learning

# %% [markdown]
# ## Name:RAJ YADAV

# %% [markdown]
# ## Class:B_B4

# %% [markdown]
# ## Roll No:48

# %% [markdown]
# # S-Algorithm

# %%
import pandas as pd
data=pd.read_csv("enjoy.csv")
data
# Out:
#       Sky AirTemp Humidity    Wind Water Forecast EnjoySport
# 0   Sunny    Warm   Normal  Strong  Warm     Same        Yes
# 1   Sunny    Warm     High  Strong  Warm     Same        Yes
# 2   Rainy    Cold     High  Strong  Warm   Change         No
# 3   Sunny    Warm     High  Strong  Cool   Change        Yes
# 4   Sunny    Cold   Normal    Weak  Warm     Same         No
# 5  Cloudy    Warm   Normal    Weak  Warm     Same         No
# 6   Sunny    Warm   Normal    Weak  Cool     Same        Yes
# 7   Rainy    Warm     High    Weak  Cool   Change         No
# 8   Sunny    Warm   Normal  Strong  Cool     Same        Yes
# 9   Sunny    Warm     High    Weak  Warm     Same        Yes

# %%
data.head()
# Out:
#      Sky AirTemp Humidity    Wind Water Forecast EnjoySport
# 0  Sunny    Warm   Normal  Strong  Warm     Same        Yes
# 1  Sunny    Warm     High  Strong  Warm     Same        Yes
# 2  Rainy    Cold     High  Strong  Warm   Change         No
# 3  Sunny    Warm     High  Strong  Cool   Change        Yes
# 4  Sunny    Cold   Normal    Weak  Warm     Same         No

# %%
X=data.iloc[:,:-1].values

y=data.iloc[:,-1].values

# %%
import numpy as np

def find_s(X,y):
    hypothesis=None
    
    print("Intial Hypothesis:",hypothesis)
    for i in range(len(X)):
        if y[i]=="Yes":
            if hypothesis is None:
                hypothesis=X[i].copy()
            else:
                for j in range(len(hypothesis)):
                    if hypothesis[j] !=X[i][j]:
                        hypothesis[j]="?"
        print(f"\nAfter training example{i+1}")
        print(hypothesis)
    return hypothesis
final_hypothesis=find_s(X,y)

print("\nFinal Hypothesis")
# Out:
# Intial Hypothesis: None
#
# After training example1
# ['Sunny' 'Warm' 'Normal' 'Strong' 'Warm' 'Same']
#
# After training example2
# ['Sunny' 'Warm' '?' 'Strong' 'Warm' 'Same']
#
# After training example3
# ['Sunny' 'Warm' '?' 'Strong' 'Warm' 'Same']
#
# After training example4
# ['Sunny' 'Warm' '?' 'Strong' '?' '?']
#
# After training example5
# ['Sunny' 'Warm' '?' 'Strong' '?' '?']
#
# After training example6
# ['Sunny' 'Warm' '?' 'Strong' '?' '?']
#
# After training example7
# ['Sunny' 'Warm' '?' '?' '?' '?']
#
# After training example8
# ['Sunny' 'Warm' '?' '?' '?' '?']
#
# After training example9
# ['Sunny' 'Warm' '?' '?' '?' '?']
#
# After training example10
# ['Sunny' 'Warm' '?' '?' '?' '?']
#
# Final Hypothesis

# %% [markdown]
# # Candidate Elimination Algorithm

# %%
def candidate_elimination(concepts,target):
    specific=concepts[0].copy()
    general=[["?"for i in range(len(specific))]]
    print("Intial S:",specific)
    print("Intial G:",general)
    for i,h in enumerate(concepts):
        if target[i]=="Yes":
            for x in range(len(specific)):
                if h[x]!=specific[x]:
                    specific[x]="?"
        else:
            for x in range(len(specific)):
                if h[x]!=specific[x]:
                    general.append(["?" if j!=x else specific[x] for j in range(len(specific))])
        print("\nExample",i+1)
        print("S=",specific)
        print("G=",general)
    return specific,general
S,G=candidate_elimination(X,y)

print("\nFinal Specific Boundary")
print(S)
print("\nFinal General Boundary:")
for g in G:
    print(g)
# Out:
# Intial S: ['Sunny' 'Warm' 'Normal' 'Strong' 'Warm' 'Same']
# Intial G: [['?', '?', '?', '?', '?', '?']]
#
# Example 1
# S= ['Sunny' 'Warm' 'Normal' 'Strong' 'Warm' 'Same']
# G= [['?', '?', '?', '?', '?', '?']]
#
# Example 2
# S= ['Sunny' 'Warm' '?' 'Strong' 'Warm' 'Same']
# G= [['?', '?', '?', '?', '?', '?']]
#
# Example 3
# S= ['Sunny' 'Warm' '?' 'Strong' 'Warm' 'Same']
# G= [['?', '?', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', 'Same']]
#
# Example 4
# S= ['Sunny' 'Warm' '?' 'Strong' '?' '?']
# G= [['?', '?', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', 'Same']]
#
# Example 5
# S= ['Sunny' 'Warm' '?' 'Strong' '?' '?']
# ...

# %%
# !git config --global user.name "Raj Yadav"
# !git config --global user.email "rajyadav5991@gmail.com"

# !git clone https://github.com/Rajy777/ML_LAB_RAJYADAV.git
# %cd ML_LAB_RAJYADAV

# !git add .
# !git commit -m "Add Jupyter notebook"
# !git branch -M main
# !git push -u origin main
# Out:
# C:\Users\ASUS ROG\machine _learning\ML_LAB_RAJYADAV
# Cloning into 'ML_LAB_RAJYADAV'...
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# branch 'main' set up to track 'origin/main'.
# Everything up-to-date

# %%
# %cd r"C:\Users\ASUS ROG\machine _learning\ML-Lab3_B_B4_48"

# !git status
# !git add .
# !git commit -m "Add ML lab notebook"
# !git push origin main
# Out:
# [WinError 123] The filename, directory name, or volume label syntax is incorrect: 'r"C:\\Users\\ASUS ROG\\machine _learning\\ML-Lab3_B_B4_48'
# C:\Users\ASUS ROG\machine _learning\ML_LAB_RAJYADAV
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !git init
# !git remote remove origin 2>/dev/null
# !git remote add origin https://github.com/Rajy777/ML_LAB_RAJYADAV.git
# !git add .
# !git commit -m "Upload ML lab notebook"
# !git branch -M main
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in C:/Users/ASUS ROG/machine _learning/ML_LAB_RAJYADAV/.git/
# The system cannot find the path specified.
# error: remote origin already exists.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# branch 'main' set up to track 'origin/main'.
# Everything up-to-date

# %%
# !git init
# !git remote remove origin 2>/dev/null
# !git remote add origin https://github.com/Rajy777/ML_LAB_RAJYADAV.git
# !git add "ML-Lab3_B_B_48.ipynb"
# !git commit -m "Add ML Lab 3 notebook"
# !git branch -M main
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in C:/Users/ASUS ROG/machine _learning/ML_LAB_RAJYADAV/.git/
# The system cannot find the path specified.
# error: remote origin already exists.
# fatal: pathspec 'ML-Lab3_B_B_48.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# branch 'main' set up to track 'origin/main'.
# Everything up-to-date
